# %% [markdown]
# Create datasets.

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
from tf_utils1 import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %matplotlib inline
np.random.seed(1)

# %%
import zipfile as zf
files = zf.ZipFile("datasetsAug.zip", 'r')
files.extractall('')
files.close()

# %%
import numpy as np
import os
from matplotlib import pyplot as plt
import cv2
import random
import pickle


file_list = []
class_list = []

DATADIR = "datasetsAug/train_crown"

# All the categories you want your neural network to detect
CATEGORIES = ["good", "bright", "date", "flare", "foreign", "scratch"]

# The size of the images that your neural network will use
IMG_SIZE = 120

# Checking or all images in the data folder
for category in CATEGORIES :
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)


training_data = []

def create_training_data():
    for category in CATEGORIES :
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try :
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)[:,:,::-1]
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
img3 = img_array[:,:,::-1]
plt.imshow(img3)


create_training_data()

random.shuffle(training_data)

X = [] #features
y = [] #labels

for features, label in training_data:
	X.append(features)
	y.append(label)


print("To the end")
# Out:
# To the end

# %%
hf = h5py.File('datasets_Aug/train_crown.h5', 'w')
hf.create_dataset('X', data=X)
hf.create_dataset('y', data=y)
hf.close()
print("Completed datasets creation.")
# Out:
# Completed datasets creation.
